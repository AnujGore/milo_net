# %%
import json
import numpy as np
import matplotlib.pyplot as plt
from flax.serialization import from_bytes
import os
import sys
import jax
import jax.numpy as jnp
import time
import tensorflow_datasets as tfds  # TFDS to download MNIST.
import tensorflow as tf  # TensorFlow / `tf.data` operations.
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))  # Moves one directory up
sys.path.append(project_root)

from src.model import MiloMLP, CNN, MiloWCon
from src.train import create_state_MLP
from src.utils import preprocess

plt.rcParams.update({
    "font.family": "sans-serif",
    "font.sans-serif": ["Helvetica", "Arial", "DejaVu Sans"]
    })

device = jax.devices("cpu")[0] #Currently CPU
rng = jax.random.PRNGKey(0)

# %%
BATCH_SIZE = 32
rng = jax.random.PRNGKey(0)
device = jax.devices("cpu")[0]

# %%
milo_con_multichannel = MiloWCon(
    input_dim=(8, 8), 
    hidden_layer_dim=[(16, 16), (10, 1)],
    output_dim=(10, 1),
    num_channels=3
)

milo_multichannel = MiloMLP(
    input_dim=(32, 32), 
    hidden_layer_dim=[(64, 64), (32, 32), (24, 18), (16, 9), (10, 1)],
    output_dim=(10, 1),
    num_channels=3
)

cnn_model = CNN()

milo_con_state_template  = create_state_MLP(rng, milo_con_multichannel, 0, data_size=(BATCH_SIZE, 32, 32, 3), device=device)
milo_state_template  = create_state_MLP(rng, milo_multichannel, 0, data_size=(BATCH_SIZE, 32, 32, 3), device=device)
cnn_state_template  = create_state_MLP(rng, cnn_model, 0, data_size=(BATCH_SIZE, 32, 32, 3), device=device)

with open("D:\Toolkit\Backup\Personal Projects\milo_net\models\milo_cifar_best_state.msgpack", "rb") as f:
    milo_best_state = from_bytes(milo_state_template, f.read())

with open("D:\Toolkit\Backup\Personal Projects\milo_net\models\cnn_cifar_best_state.msgpack", "rb") as f:
    cnn_best_state = from_bytes(cnn_state_template, f.read())

with open("D:\Toolkit\Backup\Personal Projects\milo_net\models\milo_con_cifar_best_state.msgpack", "rb") as f:
    milo_con_best_state = from_bytes(milo_con_state_template, f.read())

# %%
# --- Load metrics ---
with open("D:\Toolkit\Backup\Personal Projects\milo_net\models\cifar_metrics_history.json", "r") as f:
    metrics = json.load(f)

# --- Accuracy Plot ---
plt.figure(figsize=(16, 10))
plt.plot(metrics['milo_accuracy'], label='Milo', marker = "s")
plt.fill_between(range(len(metrics['milo_accuracy'])),
                 np.array(metrics['milo_accuracy']) - np.array(metrics['milo_accuracy_std']),
                 np.array(metrics['milo_accuracy']) + np.array(metrics['milo_accuracy_std']),
                 alpha=0.2)

plt.plot(metrics['milo_con_accuracy'], label='Milo (with Convolutions)', marker = "v")
plt.fill_between(range(len(metrics['milo_con_accuracy'])),
                 np.array(metrics['milo_con_accuracy']) - np.array(metrics['milo_con_accuracy_std']),
                 np.array(metrics['milo_con_accuracy']) + np.array(metrics['milo_con_accuracy_std']),
                 alpha=0.2)

plt.plot(metrics['cnn_accuracy'], label='CNN', marker = "o")
plt.fill_between(range(len(metrics['cnn_accuracy'])),
                 np.array(metrics['cnn_accuracy']) - np.array(metrics['cnn_accuracy_std']),
                 np.array(metrics['cnn_accuracy']) + np.array(metrics['cnn_accuracy_std']),
                 alpha=0.2)
plt.title("Training Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)
plt.show()

max_milo_accuracy = np.max(metrics['milo_accuracy'])
max_milo_con_accuracy = np.max(metrics['milo_con_accuracy'])
max_cnn_accuracy = np.max(metrics['cnn_accuracy'])

# Print results
print(f"Highest Milo accuracy: {max_milo_accuracy:.4f}")
print(f"Highest Milo (with Convolutions) accuracy: {max_milo_con_accuracy:.4f}")
print(f"Highest CNN accuracy: {max_cnn_accuracy:.4f}")
# Out:
# Highest Milo accuracy: 0.8303
# Highest Milo (with Convolutions) accuracy: 0.8839
# Highest CNN accuracy: 0.9918

# %%
plt.figure(figsize=(16, 10))
plt.plot(metrics['milo_loss'], label='Milo', marker = "s")
plt.fill_between(range(len(metrics['milo_loss'])),
                 np.array(metrics['milo_loss']) - np.array(metrics['milo_loss_std']),
                 np.array(metrics['milo_loss']) + np.array(metrics['milo_loss_std']),
                 alpha=0.2)
plt.plot(metrics['milo_con_loss'], label='Milo (with Convolutions)', marker = "v")
plt.fill_between(range(len(metrics['milo_con_loss'])),
                 np.array(metrics['milo_con_loss']) - np.array(metrics['milo_con_loss_std']),
                 np.array(metrics['milo_con_loss']) + np.array(metrics['milo_con_loss_std']),
                 alpha=0.2)
plt.plot(metrics['cnn_loss'], label='CNN', marker = "o")
plt.fill_between(range(len(metrics['cnn_loss'])),
                 np.array(metrics['cnn_loss']) - np.array(metrics['cnn_loss_std']),
                 np.array(metrics['cnn_loss']) + np.array(metrics['cnn_loss_std']),
                 alpha=0.2)
plt.title("Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

min_milo_loss = np.min(metrics['milo_loss'])
min_milo_con_loss = np.min(metrics['milo_con_loss'])
min_cnn_loss = np.min(metrics['cnn_loss'])

# Print results
print(f"Lowest Milo loss: {min_milo_loss:.4f}")
print(f"Lowest Milo (with Convolutions) loss: {min_milo_con_loss:.4f}")
print(f"Lowest CNN loss: {min_cnn_loss:.4f}")
# Out:
# Lowest Milo loss: 0.4526
# Lowest Milo (with Convolutions) loss: 0.3237
# Lowest CNN loss: 0.0257

# %%
total_milo_time = sum(metrics['milo_time'])
total_milo_std = np.sqrt(sum(np.array(metrics['milo_time_std'])**2))

total_milo_con_time = sum(metrics['milo_con_time'])
total_milo_con_std = np.sqrt(sum(np.array(metrics['milo_con_time_std'])**2))

total_cnn_time = sum(metrics['cnn_time'])
total_cnn_std = np.sqrt(sum(np.array(metrics['cnn_time_std'])**2))

print(f"Total Milo training time: {total_milo_time:.2f} ± {total_milo_std:.2f} seconds")
print(f"Total CNN training time: {total_cnn_time:.2f} ± {total_cnn_std:.2f} seconds")
print(f"Total Milo (with Convolutions) training time: {total_milo_con_time:.2f} ± {total_milo_con_std:.2f} seconds")
# Out:
# Total Milo training time: 3.19 ± 0.21 seconds
# Total CNN training time: 6.04 ± 0.15 seconds
# Total Milo (with Convolutions) training time: 7.16 ± 0.22 seconds

# %%
from jax.flatten_util import ravel_pytree

# --- Parameter count ---
def count_params(params):
    flat_params, _ = ravel_pytree(params)
    return flat_params.shape[0]

print(f"Milo params: {count_params(milo_best_state.params):,}")
print(f"Milo (with Convolutions) params: {count_params(milo_con_best_state.params):,}")
print(f"CNN params:  {count_params(cnn_best_state.params):,}")
# Out:
# Milo params: 48,514
# Milo (with Convolutions) params: 26,611
# CNN params:  545,098

# %%
milo_size_mb = os.path.getsize("D:\Toolkit\Backup\Personal Projects\milo_net\models\milo_cifar_best_state.msgpack") / (1024**2)
milo_con_size_mb = os.path.getsize("D:\Toolkit\Backup\Personal Projects\milo_net\models\milo_con_cifar_best_state.msgpack") / (1024**2)
cnn_size_mb = os.path.getsize("D:\Toolkit\Backup\Personal Projects\milo_net\models\cnn_cifar_best_state.msgpack") / (1024**2)

print(f"Milo model size: {milo_size_mb:.2f} MB")
print(f"Milo (with Convolutions) model size: {milo_con_size_mb:.2f} MB")
print(f"CNN model size:  {cnn_size_mb:.2f} MB")
# Out:
# Milo model size: 0.56 MB
# Milo (with Convolutions) model size: 0.31 MB
# CNN model size:  6.24 MB

# %%
test_ds, info = tfds.load('cifar10', split='test', with_info=True)
test_ds = test_ds.map(preprocess).batch(32, drop_remainder=True).prefetch(1)

# %%
def benchmark_inference(apply_fn, params, image_batch):
    image_batch = jnp.array(image_batch)
    variables = {'params': params}

    # Warm-up
    apply_fn(variables, image_batch)
    jax.block_until_ready(apply_fn(variables, image_batch))

    start = time.time()
    apply_fn(variables, image_batch)
    jax.block_until_ready(apply_fn(variables, image_batch))
    end = time.time()

    return (end - start) / len(image_batch)

# %%
cnn_infer_times = []; milo_infer_times = []; milo_con_infer_times = []
for batch in test_ds:
    cnn_infer_time  = benchmark_inference(cnn_best_state.apply_fn, cnn_best_state.params, batch[0])
    milo_infer_time = benchmark_inference(milo_best_state.apply_fn, milo_best_state.params, batch[0])
    milo_con_infer_time = benchmark_inference(milo_con_best_state.apply_fn, milo_con_best_state.params, batch[0])

    cnn_infer_times.append(cnn_infer_time)
    milo_infer_times.append(milo_infer_time)
    milo_con_infer_times.append(milo_con_infer_time)

cnn_avg_time = np.mean(cnn_infer_times)
cnn_std_time = np.std(cnn_infer_times)

milo_avg_time = np.mean(milo_infer_times)
milo_std_time = np.std(milo_infer_times)

milo_con_avg_time = np.mean(milo_con_infer_times)
milo_con_std_time = np.std(milo_con_infer_times)

print(f"CNN average inference time:  {cnn_avg_time * 1e3:.3f} ms/image ± {cnn_std_time * 1e3:.3f} ms")
print(f"Milo average inference time: {milo_avg_time * 1e3:.3f} ms/image ± {milo_std_time * 1e3:.3f} ms")
print(f"Milo (with Convolutions) average inference time: {milo_con_avg_time * 1e3:.3f} ms/image ± {milo_con_std_time * 1e3:.3f} ms")
# Out:
# CNN average inference time:  1.130 ms/image ± 0.140 ms
# Milo average inference time: 3.782 ms/image ± 0.314 ms
# Milo (with Convolutions) average inference time: 1.813 ms/image ± 0.339 ms

# %%
def get_preds_and_labels(state, test_ds, add_channel=False):
    all_preds = []
    all_labels = []

    for batch in test_ds:

        logits = state.apply_fn({'params': state.params}, np.array(batch[0]))
        preds = np.argmax(np.array(logits), axis=-1)

        labels = np.array(batch[1])

        preds = preds.astype(np.int32).flatten()
        labels = labels.astype(np.int32).flatten()

        all_preds.append(preds)
        all_labels.append(labels)

    return np.concatenate(all_preds), np.concatenate(all_labels)


def plot_cm(ax, cm, title):
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues, vmin=0, vmax=1)
    ax.set_title(title)
    tick_marks = np.arange(10)
    ax.set_xticks(tick_marks)
    ax.set_yticks(tick_marks)
    ax.set_xlabel("Predicted")
    ax.set_ylabel("True")

    # Cell labels
    for i in range(10):
        for j in range(10):
            val = cm[i, j]
            ax.text(j, i, f"{val:.2f}",
                    ha="center", va="center",
                    color="white" if val > 0.5 else "black")

# %%
# Get predictions
milo_preds, milo_labels = get_preds_and_labels(milo_best_state, test_ds, add_channel=False)
milo_con_preds, milo_con_labels = get_preds_and_labels(milo_con_best_state, test_ds, add_channel=False)
cnn_preds, cnn_labels   = get_preds_and_labels(cnn_best_state, test_ds, add_channel=True)

# Compute normalized confusion matrices
def normalize_cm(cm):
    return cm.astype('float') / cm.sum(axis=1, keepdims=True)

milo_cm = normalize_cm(confusion_matrix(milo_labels, milo_preds))
cnn_cm  = normalize_cm(confusion_matrix(cnn_labels, cnn_preds))
milo_con_cm  = normalize_cm(confusion_matrix(milo_con_labels, milo_con_preds))

# --- Plot side-by-side ---
fig, axes = plt.subplots(1, 3, figsize=(14, 6))

# Plot both confusion matrices
plot_cm(axes[0], milo_cm, "Milo Normalized Confusion Matrix")
plot_cm(axes[1], milo_con_cm, "Milo (with Convolutions) Normalized Confusion Matrix")
plot_cm(axes[2], cnn_cm, "CNN Normalized Confusion Matrix")

# Add colorbar
fig.colorbar(axes[0].images[0], ax=axes, orientation='vertical', fraction=0.02, pad=0.04)
plt.show()

# %%
label_names = info.features['label'].names
for name in label_names:
    print(name, label_names.index(name))
# Out:
# airplane 0
# automobile 1
# bird 2
# cat 3
# deer 4
# dog 5
# frog 6
# horse 7
# ship 8
# truck 9
